# %% [markdown]
# # A regression model using the Keras library to model the same data about concrete compressive strength

# %% [markdown]
# Name: Adeyemi Oluwaseyi Emmanuel

# %% [markdown]
# This is the link to the data
# https://cocl.us/concrete_data

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
## Importing important libraries necessary for the task.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# We import the csv file [Concrete_data.csv]
# and we also asign it to a variable called data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/LegendSeyi/Dataset/main/concrete_data.csv')

# %% [markdown]
# - We check the details of the dataset, to see if it need to be cleaned
# - If there are null values
# - If there are missing/ duplicated rows

# %%
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
data.shape
# Out:
# (1030, 9)

# %% [markdown]
# In the data set, we have **1030** rows and **9 colomns**

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# from the above the data is clean and there are no null values

# %% [markdown]
# ## REGRESSION WITH KERAS

# %% [markdown]
# We start by importing the Keras library

# %%
import keras

# %%
# Importing other packages from keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %% [markdown]
# We Split the data set

# %%
data_columns = data.columns

predictors = data[data_columns[data_columns != 'Strength']] # all columns except Strength
target = data['Strength'] # Strength column

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ### Training and testing the network

# %%
# build the model
model = regression_model()

# %%
# Out:
# Epoch 1/100
# 23/23 - 2s - loss: 1699.7325 - val_loss: 1194.7183 - 2s/epoch - 78ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1614.1080 - val_loss: 1118.9312 - 86ms/epoch - 4ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1485.6589 - val_loss: 996.2328 - 84ms/epoch - 4ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 1270.7980 - val_loss: 812.3295 - 76ms/epoch - 3ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 959.1611 - val_loss: 587.9474 - 83ms/epoch - 4ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 621.0389 - val_loss: 372.0201 - 83ms/epoch - 4ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 369.4539 - val_loss: 239.3009 - 76ms/epoch - 3ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 261.6884 - val_loss: 190.4654 - 84ms/epoch - 4ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 233.0567 - val_loss: 178.2083 - 103ms/epoch - 4ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 216.9838 - val_loss: 176.4258 - 84ms/epoch - 4ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 204.6237 - val_loss: 174.4639 - 76ms/epoch - 3ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 194.9272 - val_loss: 168.8769 - 84ms/epoch - 4ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 187.6508 - val_loss: 167.9546 - 81ms/epoch - 4ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 180.4785 - val_loss: 166.6699 - 89ms/epoch - 4ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 175.5405 - val_loss: 165.8153 - 82ms/epoch - 4ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 170.3462 - val_loss: 162.4016 - 74ms/epoch - 3ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 166.4216 - val_loss: 159.7727 - 84ms/epoch - 4ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 162.5054 - val_loss: 160.1903 - 88ms/epoch - 4ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 159.3631 - val_loss: 158.7852 - 87ms/epoch - 4ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 156.3612 - val_loss: 157.9506 - 84ms/epoch - 4ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 153.7998 - val_loss: 156.2361 - 98ms/epoch - 4ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 151.2652 - val_loss: 155.6468 - 77ms/epoch - 3ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 149.0113 - val_loss: 154.5040 - 82ms/epoch - 4ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 147.2021 - val_loss: 152.3630 - 78ms/epoch - 3ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 144.7665 - val_loss: 152.6533 - 87ms/epoch - 4ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 142.7950 - val_loss: 153.2330 - 83ms/epoch - 4ms/step
# Epoch 27/100
# 23/23 - 0s - loss:
ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 48.4590 - val_loss: 126.9940 - 79ms/epoch - 3ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 47.2892 - val_loss: 124.8052 - 85ms/epoch - 4ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 45.7956 - val_loss: 127.7231 - 79ms/epoch - 3ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 44.9693 - val_loss: 123.7319 - 81ms/epoch - 4ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 44.4636 - val_loss: 119.0661 - 78ms/epoch - 3ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 43.5748 - val_loss: 125.0971 - 76ms/epoch - 3ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 42.5205 - val_loss: 135.6707 - 81ms/epoch - 4ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 41.3880 - val_loss: 122.2834 - 80ms/epoch - 3ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 40.6179 - val_loss: 142.3749 - 81ms/epoch - 4ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 39.6852 - val_loss: 134.3965 - 88ms/epoch - 4ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 39.1718 - val_loss: 145.4903 - 87ms/epoch - 4ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 38.7124 - val_loss: 143.6487 - 76ms/epoch - 3ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 37.6095 - val_loss: 140.3030 - 75ms/epoch - 3ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 37.1457 - val_loss: 140.5179 - 79ms/epoch - 3ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 37.3076 - val_loss: 151.5063 - 83ms/epoch - 4ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 36.0820 - val_loss: 142.0100 - 94ms/epoch - 4ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 35.6061 - val_loss: 144.7669 - 79ms/epoch - 3ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 35.2677 - val_loss: 147.1421 - 83ms/epoch - 4ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 34.7659 - val_loss: 159.8774 - 85ms/epoch - 4ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 34.3645 - val_loss: 153.2201 - 78ms/epoch - 3ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 33.3552 - val_loss: 149.0737 - 77ms/epoch - 3ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 33.4210 - val_loss: 156.2917 - 145ms/epoch - 6ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 32.6101 - val_loss: 142.8268 - 151ms/epoch - 7ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 32.5123 - val_loss: 152.7955 - 116ms/epoch - 5ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 32.1922 - val_loss: 160.6575 - 120ms/epoch - 5ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 32.0077 - val_loss: 166.8781 - 155ms/epoch - 7ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 31.3259 - val_loss: 151.4541 - 127ms/epoch - 6ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 30.6632 - val_loss: 170.4790 - 109ms/epoch - 5ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 31.1217 - val_loss: 161.2959 - 116ms/epoch - 5ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 30.4748 - val_loss: 149.2022 - 122ms/epoch - 5ms/step

# %%
from keras.utils import to_categorical

# %%
import pandas as pd
from sklearn.model_selection import train_test_split


X = data.drop('Strength', axis=1)
y = data['Strength']

# Repeat the process 50 times
for _ in range(50):
    # Randomly split the data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Build the neural network model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_dim=X.shape[1]))
    model.add(Dense(1))
    model.compile(optimizer=Adam(), loss='mean_squared_error')

    # Train the model
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # Evaluate the model on the test set
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
# Out:
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# **50 mean squared errors**

# %%
# Calculate the mean and standard deviation of the mean squared errors
mean_mse = np.mean(mse_list)
std_mse = np.std(mse_list)

print(f"Mean MSE: {mean_mse:.2f}")
print(f"Standard Deviation of MSE: {std_mse:.2f}")
# Out:
# Mean MSE: 374.65
# Standard Deviation of MSE: 436.27

# %% [markdown]
# **Mean MSE: 374.65**
#
# **Standard Deviation of MSE: 436.27**
